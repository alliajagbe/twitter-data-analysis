# %% [markdown]
# # Importing the Required Libraries

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Generating the Twitter Data

# %%
categories = ['sports', 'politics', 'business', 'technology', 'entertainment', 'fashion', 'food', 'travel', 'health', 'science']

data = []
for i in range(100000):
    category = random.choice(categories)
    likes = random.randint(0, 100000)
    retweets = random.randint(0, 10000)
    comments = random.randint(0, 1000)
    data.append((category, likes, retweets, comments))

for category, likes, retweets, comments in data:
    print(f'Category: {category}, Likes: {likes}, Retweets: {retweets}, Comments: {comments}')
